# %% [markdown]
# <a href="https://colab.research.google.com/github/gilvandrocesardemedeiros/DCA_UFRN_Data-Science/blob/main/Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
partidos = ["solidariedade", "pv", "avante", "cidadania", "dc", "dem", "mdb", "novo", "patriota", "pcb", "pcdob", "pco", "pdt", "phs", 
            "pl", "pmb", "pmn", "pode", "pp", "ppl", "pros", "prp", "prtb", "psb", "psc", "psd", "psdb", 
            "psl", "psol", "pstu", "pt", "ptb", "ptc", "rede", "republicanos", "up"]
partidos = [partido.upper() for partido in partidos]

ufs = ["ac","al","am","ap","ba","ce","df","es","go","ma","mg","ms","mt","pa","pb","pe","pi","pr","rj","rn",
     "ro","rr","rs","sc","se","sp","to","zz"]
ufs = [uf.upper() for uf in ufs]

# %%
#UF de interesse
uf = "AC"

# %%
dados2018 = pd.read_csv("https://raw.githubusercontent.com/gilvandrocesardemedeiros/DCA_UFRN_Data-Science/main/consulta_cand_2018/consulta_cand_2018_{}.csv".format(uf),
                        sep = ";", encoding = "latin-1")

# %%
dados2018.head()
# Out:
#    DT_GERACAO HH_GERACAO  ...  DS_SITUACAO_CANDIDATO_URNA  ST_CANDIDATO_INSERIDO_URNA
# 0  11/02/2021   19:17:57  ...                    DEFERIDO                         SIM
# 1  11/02/2021   19:17:57  ...                    DEFERIDO                         SIM
# 2  11/02/2021   19:17:57  ...                    DEFERIDO                         SIM
# 3  11/02/2021   19:17:57  ...                    DEFERIDO                         SIM
# 4  11/02/2021   19:17:57  ...                    DEFERIDO                         SIM
#
# [5 rows x 63 columns]

# %%
dados2020 = pd.read_csv("https://raw.githubusercontent.com/gilvandrocesardemedeiros/DCA_UFRN_Data-Science/main/consulta_cand_2020/consulta_cand_2020_{}.csv".format(uf),
                        sep = ";", encoding = "latin-1")

# %%
dados2020.head()
# Out:
#    DT_GERACAO HH_GERACAO  ...  DS_SITUACAO_CANDIDATO_URNA  ST_CANDIDATO_INSERIDO_URNA
# 0  26/02/2021   12:18:48  ...                    DEFERIDO                         SIM
# 1  26/02/2021   12:18:48  ...                    DEFERIDO                         SIM
# 2  26/02/2021   12:18:48  ...                    DEFERIDO                         SIM
# 3  26/02/2021   12:18:48  ...                    DEFERIDO                         SIM
# 4  26/02/2021   12:18:48  ...                    DEFERIDO                         SIM
#
# [5 rows x 63 columns]
